# %% [markdown]
# <a href="https://colab.research.google.com/github/purvabadhe/AI-in-Finance-/blob/main/AIF_Exp_2_EDA_Stock_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install yfinance
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.7.4)

# %%
ONGC_df = pd.read_csv("ONGC.NS.csv")
IOC_df =  pd.read_csv("IOC.NS.csv")
BPCL_df = pd.read_csv("BPCL.NS.csv")

# %%
ONGC_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1996-01-01   18.888887   18.972221   18.777777   18.799999    5.640413
# 1     1996-01-02   18.799999   19.277777   18.844444   19.088888    5.727084
# 2     1996-01-03   19.333332   19.333332   18.888887   18.888887    5.667083
# 3     1996-01-04   18.888887   18.900000   18.500000   18.894444    5.668746
# 4     1996-01-05   18.894444   18.905556   18.666666   18.900000    5.670414
# ...          ...         ...         ...         ...         ...         ...
# 7194  2024-08-12  332.750000  344.700012  329.899994  341.299988  341.299988
# 7195  2024-08-13  344.100006  345.000000  332.950012  335.899994  335.899994
# 7196  2024-08-14  335.850006  336.500000  326.799988  328.149994  328.149994
# 7197  2024-08-16  332.549988  335.750000  328.649994  329.600006  329.600006
# 7198  2024-08-19  335.000000  338.750000  333.549988  335.299988  335.299988
#
#           Volume
# 0        10800.0
# 1        27000.0
# 2        10800.0
# 3        41400.0
# 4        46800.0
# ...          ...
# 7194  34754596.0
# 7195  28943385.0
# 7196  17812763.0
# 7197  16584396.0
# 7198  19636518.0
#
# [7199 rows x 7 columns]

# %% [markdown]
#   Dataframe showing historical data of ONGC(Oil and Natural Gas Corp.) stocks

# %%
IOC_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1996-04-15   18.055555   18.055555   17.222221   17.222221    4.924090
# 1     1996-04-16   17.222221   17.222221   17.222221   17.222221    4.924090
# 2     1996-04-17   17.222221   17.222221   17.222221   17.222221    4.924090
# 3     1996-04-18   17.222221   18.055555   17.222221   17.222221    4.924090
# 4     1996-04-19   17.222221   17.222221   17.222221   17.222221    4.924090
# ...          ...         ...         ...         ...         ...         ...
# 7119  2024-08-12  168.000000  171.000000  167.789993  169.160004  169.160004
# 7120  2024-08-13  168.309998  168.690002  163.009995  164.119995  164.119995
# 7121  2024-08-14  165.009995  165.639999  163.100006  163.740005  163.740005
# 7122  2024-08-16  165.250000  167.449997  164.850006  167.169998  167.169998
# 7123  2024-08-19  170.000000  170.809998  169.320007  170.080002  170.080002
#
#           Volume
# 0        43200.0
# 1            0.0
# 2         3600.0
# 3        14400.0
# 4         7200.0
# ...          ...
# 7119  11563339.0
# 7120  16620160.0
# 7121  14369897.0
# 7122  10622879.0
# 7123  11457875.0
#
# [7124 rows x 7 columns]

# %% [markdown]
#   Dataframe showing historical data of IOC(Indian Oil Corp.) stocks

# %%
BPCL_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1996-01-02    9.916666    9.833333    9.750000    9.750000    3.116946
# 1     1996-01-03    9.739583    9.739583    9.739583    9.739583    3.113616
# 2     1996-01-04    9.739583    9.791666    9.645833    9.791666    3.130266
# 3     1996-01-05    9.791666    9.791666    9.791666    9.791666    3.130266
# 4     1996-01-08    9.791666    9.687500    9.541666    9.541666    3.050344
# ...          ...         ...         ...         ...         ...         ...
# 7193  2024-08-12  331.799988  336.799988  330.200012  333.399994  333.399994
# 7194  2024-08-13  331.950012  332.750000  321.000000  321.700012  321.700012
# 7195  2024-08-14  321.700012  327.450012  320.649994  325.049988  325.049988
# 7196  2024-08-16  326.049988  333.799988  326.049988  332.500000  332.500000
# 7197  2024-08-19  337.799988  345.549988  336.350006  343.799988  343.799988
#
#           Volume
# 0         9600.0
# 1         4800.0
# 2         4800.0
# 3            0.0
# 4         4800.0
# ...          ...
# 7193  12253716.0
# 7194   9757429.0
# 7195   8457477.0
# 7196   8214443.0
# 7197  17875728.0
#
# [7198 rows x 7 columns]

# %%
ONGC_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  7189.000000  7189.000000  7189.000000  7189.000000  7189.000000
# mean    123.494962   125.316711   121.450003   123.285471    77.803070
# std      73.835102    74.833166    72.694101    73.698781    57.885717
# min      10.622222    11.311111    10.566666    10.988888     3.416594
# 25%      40.416664    41.005554    39.905556    40.288887    16.193991
# 50%     139.833328   141.766663   137.500000   139.550003    86.411949
# 75%     180.766663   183.050003   177.866669   180.366669   114.724960
# max     344.100006   345.000000   337.149994   341.750000   341.750000
#
#              Volume
# count  7.189000e+03
# mean   8.621646e+06
# std    1.152873e+07
# min    0.000000e+00
# 25%    1.704600e+06
# 50%    5.967010e+06
# 75%    1.100135e+07
# max    2.922325e+08

# %%
IOC_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  7114.000000  7114.000000  7114.000000  7114.000000  7114.000000
# mean     51.810798    52.551444    50.983734    51.710535    31.398488
# std      36.395791    36.829049    35.852157    36.309245    31.028774
# min       6.000000     6.550000     5.875000     6.183333     1.936003
# 25%      21.388887    21.527777    21.111111    21.388887     6.202765
# 50%      44.418749    45.124998    43.625000    44.314583    21.380415
# 75%      69.745833    70.512497    69.014580    69.606247    45.465411
# max     202.125000   202.125000   202.125000   202.125000   184.679291
#
#              Volume
# count  7.114000e+03
# mean   8.642147e+06
# std    1.295774e+07
# min    0.000000e+00
# 25%    1.023597e+06
# 50%    4.313697e+06
# 75%    1.137103e+07
# max    3.148937e+08

# %%
BPCL_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  7188.000000  7188.000000  7188.000000  7188.000000  7188.000000
# mean     87.357707    88.664678    85.919258    87.230709    59.613750
# std      83.605141    84.686431    82.346732    83.470499    69.676598
# min       5.541666     5.604166     5.439583     5.604166     1.854495
# 25%      21.353125    21.817707    20.762501    21.232292     8.671168
# 50%      44.233334    45.212499    43.356249    44.193751    22.432136
# 75%     166.087498   168.224995   163.924995   166.106255   119.642090
# max     352.000000   359.049988   346.149994   350.049988   343.799988
#
#              Volume
# count  7.188000e+03
# mean   8.510669e+06
# std    1.066072e+07
# min    0.000000e+00
# 25%    3.042795e+06
# 50%    6.405568e+06
# 75%    1.069776e+07
# max    3.995819e+08

# %%
#Parsing Date
# Check if the 'Date' column exists in each DataFrame
print("ONGC_df columns:", ONGC_df.columns)
print("IOC_df columns:", IOC_df.columns)
print("BPCL_df columns:", BPCL_df.columns)

#Parsing Date - Only if 'Date' column is present
if 'Date' in ONGC_df.columns:
    ONGC_df['Date']=pd.to_datetime(ONGC_df['Date']).dt.date
if 'Date' in IOC_df.columns:
    IOC_df['Date']=pd.to_datetime(IOC_df['Date']).dt.date
if 'Date' in BPCL_df.columns:
    BPCL_df['Date']=pd.to_datetime(BPCL_df['Date']).dt.date
# Out:
# ONGC_df columns: Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# IOC_df columns: Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# BPCL_df columns: Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
#Dropping rows having missing values
ONGC_df=ONGC_df.dropna()
IOC_df=IOC_df.dropna()
BPCL_df=BPCL_df.dropna()

# %%
ONGC_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7189 entries, 0 to 7198
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7189 non-null   object
#  1   Open       7189 non-null   float64
#  2   High       7189 non-null   float64
#  3   Low        7189 non-null   float64
#  4   Close      7189 non-null   float64
#  5   Adj Close  7189 non-null   float64
#  6   Volume     7189 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 449.3+ KB

# %%
IOC_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7114 entries, 0 to 7123
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7114 non-null   object
#  1   Open       7114 non-null   float64
#  2   High       7114 non-null   float64
#  3   Low        7114 non-null   float64
#  4   Close      7114 non-null   float64
#  5   Adj Close  7114 non-null   float64
#  6   Volume     7114 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 444.6+ KB

# %%
BPCL_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7188 entries, 0 to 7197
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7188 non-null   object
#  1   Open       7188 non-null   float64
#  2   High       7188 non-null   float64
#  3   Low        7188 non-null   float64
#  4   Close      7188 non-null   float64
#  5   Adj Close  7188 non-null   float64
#  6   Volume     7188 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 449.2+ KB

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Step 3: Perform exploratory analysis & visualization

# %%
#Plotting Date vs Closing Price of each stock
sns.set_style("darkgrid")
plt.figure(figsize=(14,8))
plt.plot(ONGC_df.Date,ONGC_df.Close,c='red')
plt.plot(IOC_df.Date,IOC_df.Close,c='orange')
plt.plot(BPCL_df.Date,BPCL_df.Close,c='b')
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Oil Companies Stock Prices: Date Vs Closing Price")
plt.legend(["ONGC","IOC","BPCL"]);

# %% [markdown]
# ## Simple Moving Average(SMA)
#
# SMAs are commonly used to smooth price data and technical indicators. The longer the period of the SMA, the smoother the result, but the more lag that is introduced between the SMA and the source.

# %%
#Caculation of SMA for ONGC stock price
ONGC_df['Moving Average_9']=ONGC_df['Close'].rolling(window=9).mean()
ONGC_df['Moving Average_50']=ONGC_df['Close'].rolling(window=50).mean()

# %%
#Plotting SMA for ONGC for stock price
sns.set_style("whitegrid")
plt.figure(figsize=(14,8))
plt.plot(ONGC_df.Date,ONGC_df.Close,c='darkred')
plt.plot(ONGC_df.Date,ONGC_df['Moving Average_9'])
plt.plot(ONGC_df.Date,ONGC_df['Moving Average_50'])
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend(['Close','Moving_average_9','Moving_average_50'])
plt.title(":Simple Moving Average Plot:ONGC Closing Price Vs Date");

# %%
#Calculation of SMA for IOC stock price
IOC_df['Moving Average_9']=IOC_df['Close'].rolling(window=9).mean()
IOC_df['Moving Average_50']=IOC_df['Close'].rolling(window=50).mean()

# %%
#Plotting SMA for IOC for stock price
sns.set_style("darkgrid")
plt.figure(figsize=(14,8))
plt.plot(IOC_df.Date,IOC_df.Close,c='orangered')
plt.plot(IOC_df.Date,IOC_df['Moving Average_9'])
plt.plot(IOC_df.Date,IOC_df['Moving Average_50'])
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend(['Close','Moving_average_9','Moving_average_50'])
plt.title(":Simple Moving Average Plot:IOC Closing Price Vs Date");

# %%
#Caculation of SMA for BPCL stock price
BPCL_df['Moving Average_9']=BPCL_df['Close'].rolling(window=9).mean()
BPCL_df['Moving Average_50']=BPCL_df['Close'].rolling(window=50).mean()

# %%
#Plotting SMA for BPCL for stock price
sns.set_style("whitegrid")
plt.figure(figsize=(14,8))
plt.plot(BPCL_df.Date,BPCL_df.Close,c='b')
plt.plot(BPCL_df.Date,BPCL_df['Moving Average_9'])
plt.plot(BPCL_df.Date,BPCL_df['Moving Average_50'])
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend(['Close','Moving_average_9','Moving_average_50'])
plt.title("Simple Moving Average Plot:BPCL Closing Price Vs Date");

# %% [markdown]
# ## Daily Return
#
# Daily return on a stock is used to measure the day to day performance of stocks, it is the price of stocks at today’s closure compared to the price of the same stock at yesterday’s closure.  A positive return means the stock has grown in value, while a negative return means it has lost value.

# %%
#Calculating Daily Returns of each company
ONGC_df['Daily_Returns']=ONGC_df.Close.pct_change()*100
IOC_df['Daily_Returns']=IOC_df.Close.pct_change()*100
BPCL_df['Daily_Returns']=BPCL_df.Close.pct_change()*100

# %%
#Plotting Daily Return of the stocks in one output, by having subplots
fig, axes = plt.subplots(3, 1, figsize=(14,17))

# Using the axes for plotting
axes[0].stem(ONGC_df.Date,ONGC_df.Daily_Returns,'DarkRed',use_line_collection=True)
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Daily Returns')
axes[0].set_title('Daily Returns of ONGC stock')

axes[1].stem(IOC_df.Date,IOC_df.Daily_Returns,'OrangeRed',use_line_collection=True )
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Daily Returns')
axes[1].set_title('Daily Returns of IOC stock')

axes[2].stem(BPCL_df.Date,BPCL_df.Daily_Returns,'b',use_line_collection=True )
axes[2].set_xlabel('Date')
axes[2].set_ylabel('Daily Returns')
axes[2].set_title('Daily Returns of BPCL stock')
plt.tight_layout(pad=2);

# %% [markdown]
# The above stem plots(lollipop plots) give the daily returns of each company. If the vertical lines are above the red baseline it means a positive return and if the vertical lines are below the red baseline it means a negative return on that day.

# %% [markdown]
# ### Frequency of daily returns

# %%
#Plotting a histogram, to show the frequency distribution of the daily returns of ONGC
ONGC_df['Daily_Returns'].hist(color='DarkRed',bins=np.arange(-20,20,5),figsize = (10,5))
plt.xlabel('Daily Returns')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of ONGC Daily Returns');

# %%
#Plotting a histogram, to show the frequency distribution of the daily returns of IOC
IOC_df['Daily_Returns'].hist(color='OrangeRed',bins=np.arange(-20,20,5),figsize = (10,5))
plt.xlabel('Daily Returns')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of IOC Daily Returns');

# %%
#Plotting a histogram, to show the frequency distribution of the daily returns of BPCL
BPCL_df['Daily_Returns'].hist(color='mediumblue',bins=np.arange(-20,20,5),figsize = (10,5))
plt.xlabel('Daily Returns')
plt.ylabel('Frequency');
plt.title('Frequency Distribution of BPCL Daily Returns');

# %% [markdown]
# The above plots show the frequency of daily returns of each company.

# %% [markdown]
# # Step 4: Ask & answer questions about the data

# %% [markdown]
# ## Q1)Which stock is the most volatile?

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(14,8))
plt.plot(ONGC_df.Date, ONGC_df.Daily_Returns.rolling(30).std(), c='darkred')
plt.plot(IOC_df.Date, IOC_df.Daily_Returns.rolling(30).std(), c='orangered')
plt.plot(BPCL_df.Date, BPCL_df.Daily_Returns.rolling(30).std(), c='b')

plt.xlabel("Date")
plt.ylabel("Volatility")
plt.title("Oil Companies Volatility")
plt.legend(["ONGC","IOC","BPCL"]);

# %% [markdown]
# The above plot show the comparative volatility analysis among the three oil companies,viz ONGC, IOC and BPCL.We plot this by computing the 30-day(approx.1 month) rolling mean(also called moving average) of the daily returns, then compute the standard deviation and plot the values.

# %% [markdown]
# *The above plot show that BPCL stock is the most volatile for most part of the  given timeframe.*

# %% [markdown]
# ## Q2)What were the dates on which the daily returns of each company,i.e. ONGC, IOC and BPCL were the highest?

# %%
ONGC_df= ONGC_df.set_index('Date')
IOC_df= IOC_df.set_index('Date')
BPCL_df= BPCL_df.set_index('Date')

# %%
ONGC_Highest=ONGC_df.Daily_Returns.idxmax(axis=0)
IOC_Highest=IOC_df.Daily_Returns.idxmax(axis=0)
BPCL_Highest=BPCL_df.Daily_Returns.idxmax(axis=0)

# %%
print('Highest Daily Return of ONGC stock was on',str(ONGC_Highest))
print('Highest Daily Return of IOC stock was on',str(IOC_Highest))
print('Highest Daily Return of BPCL stock between was on',str(BPCL_Highest))
# Out:
# Highest Daily Return of ONGC stock was on 1999-04-27
# Highest Daily Return of IOC stock was on 1999-03-29
# Highest Daily Return of BPCL stock between was on 2005-07-28

# %%
ONGC_df=ONGC_df.reset_index()
IOC_df=IOC_df.reset_index()
BPCL_df=BPCL_df.reset_index()

# %% [markdown]
# ## Q3)Which company's stock is the most profitable?

# %%
#Calculating Annual Return
ONGC_AnnualReturn=ONGC_df.Daily_Returns.sum()
IOC_AnnualReturn=IOC_df.Daily_Returns.sum()
BPCL_AnnualReturn=BPCL_df.Daily_Returns.sum()

# %%
#Plotting the annual returns
Annual_Returns=[ONGC_AnnualReturn,IOC_AnnualReturn,BPCL_AnnualReturn]
Stock_List=['ONGC','IOCL','BPCL']

plt.figure(figsize=(12,7))
plt.bar(Stock_List,Annual_Returns,width=0.2)

plt.ylabel('Annual Return');

# %% [markdown]
# *From the above bar chart , it is clear that, IOCL's stock has the highest returns. Hence, it is the most profitable stock.*

# %% [markdown]
# ## Q4)What was the effect of COVID19 on the price of the stocks

# %%
#Changing dtype of Date to datetime64 from object
ONGC_df['Date']=pd.to_datetime(ONGC_df['Date'])
IOC_df['Date']=pd.to_datetime(IOC_df['Date'])
BPCL_df['Date']=pd.to_datetime(BPCL_df['Date'])

# %%
#Changing the index to Date for slicing
ONGC_df= ONGC_df.set_index('Date')
IOC_df= IOC_df.set_index('Date')
BPCL_df= BPCL_df.set_index('Date')

# %%
#Generating subplots
fig, axes = plt.subplots(3, 1, figsize=(14,17))
plt.figtext(.14, .90, "*COVID 19 was declared as a pandemic on 11 March 2020", c='red')
#Plot for ONGC stock price
ONGC_df_corona = ONGC_df['2020-03-11':]
axes[0].plot(ONGC_df[:'2020-03-11'].Open,'g')
axes[0].plot(ONGC_df_corona.Open,'r')
axes[0].legend(['Pre Pandemic', 'During Pandemic'])
axes[0].set_ylabel('Stock opening price');
axes[0].set_title('ONGC stock prices during COVID 19 pandemic')
#Plot for IOC stock price
IOC_df_corona = IOC_df['2020-03-11':]
axes[1].plot(IOC_df[:'2020-03-11'].Open,'g')
axes[1].plot(IOC_df_corona.Open,'r')
axes[1].legend(['Pre Pandemic', 'During Pandemic'])
axes[1].set_ylabel('Stock opening price');
axes[1].set_title('IOC stock prices during COVID 19 pandemic')
#Plot for BPCL stock price
BPCL_df_corona = BPCL_df['2020-03-11':]
axes[2].plot(BPCL_df[:'2020-03-11'].Open,'g')
axes[2].plot(BPCL_df_corona.Open,'r')
axes[2].legend(['Pre Pandemic', 'During Pandemic'])
axes[2].set_ylabel('Stock opening price');
axes[2].set_title('BPCL stock prices during COVID 19 pandemic');

# %% [markdown]
# From the plots, we can see that the COVID19 pandemic had a huge impact on the stock prices of ONGC, IOC and BPCL stocks. The day COVID19 was declared a pandemic , all the stock prices started falling. ONGC and IOC could not regain their pre covid stock prices,but BPCL stock price managed to go up after an initial low.

# %%
ONGC_df=ONGC_df.reset_index()
IOC_df=IOC_df.reset_index()
BPCL_df=BPCL_df.reset_index()
